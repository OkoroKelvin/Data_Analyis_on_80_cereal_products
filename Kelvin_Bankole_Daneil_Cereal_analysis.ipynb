# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cereal_dataset =  pd.read_csv("cereal.csv")

# %%
cereal_dataset
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     5.0       6     280        25      3     1.0  0.33  68.402973
# 1     8.0       8     135         0      3     1.0  1.00  33.983679
# 2     7.0       5     320        25      3     1.0  0.33  59.425505
# 3     8.0       0     330        25      3     1.0  0.50  93.704912
# 4    14.0       8      -1        25      3     1.0  0.75  34.384843
# ..    ...     ...     ...       ...    ...     ...   ...        ...
# 72   21.0       3      60        25      3     1.0  0.75  39.106174
# 73   13.0      12      25        25      2     1.0  1.00  27.753301
# 74   17.0       3     115        25      1     1.0  0.67  49.787445
# 75   17.0       3     110        25      1     1.0  1.00  51.592193
# 76   16.0       8      60        25      1     1.0  0.75  36.187559
#
# [77 rows x 16 columns]

# %%
cereal_dataset.head(20)
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# 5     Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# 6                 Apple Jacks   K    C       110        2    0     125    1.0
# 7                     Basic 4   G    C       130        3    2     210    2.0
# 8                   Bran Chex   R    C        90        2    1     200    4.0
# 9                 Bran Flakes   P    C        90        3    0     210    5.0
# 10               Cap'n'Crunch   Q    C       120        1    2     220    0.0
# 11                   Cheerios   G    C       110        6    2     290    2.0
# 12      Cinnamon Toast Crunch   G    C       120        1    3     210    0.0
# 13                   Clusters   G    C       110        3    2     140    2.0
# 14                Cocoa Puffs   G    C       110        1    1     180    0.0
# 15                  Corn Chex   R    C       110        2    0     280    0.0
# 16                Corn Flakes   K    C       100        2    0     290    1.0
# 17                  Corn Pops   K    C       110        1    0      90    1.0
# 18              Count Chocula   G    C       110        1    1     180    0.0
# 19         Cracklin' Oat Bran   K    C       110        3    3     140    4.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     5.0       6     280        25      3    1.00  0.33  68.402973
# 1     8.0       8     135         0      3    1.00  1.00  33.983679
# 2     7.0       5     320        25      3    1.00  0.33  59.425505
# 3     8.0       0     330        25      3    1.00  0.50  93.704912
# 4    14.0       8      -1        25      3    1.00  0.75  34.384843
# 5    10.5      10      70        25      1    1.00  0.75  29.509541
# 6    11.0      14      30        25      2    1.00  1.00  33.174094
# 7    18.0       8     100        25      3    1.33  0.75  37.038562
# 8    15.0       6     125        25      1    1.00  0.67  49.120253
# 9    13.0       5     190        25      3    1.00  0.67  53.313813
# 10   12.0      12      35        25      2    1.00  0.75  18.042851
# 11   17.0       1     105        25      1    1.00  1.25  50.764999
# 12   13.0       9      45        25      2    1.00  0.75  19.823573
# 13   13.0       7     105        25      3    1.00  0.50  40.400208
# 14   12.0      13      55        25      2    1.00  1.00  22.736446
# 15   22.0       3      25        25      1    1.00  1.00  41.445019
# 16   21.0       2      35        25      1    1.00  1.00  45.863324
# 17   13.0      12      20        25      2    1.00  1.00  35.782791
# 18   12.0      13      65        25      2    1.00  1.00  22.396513
# 19   10.0       7     160        25      3    1.00  0.50  40.448772

# %%
cereal_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       77 non-null     object
#  2   type      77 non-null     object
#  3   calories  77 non-null     int64
#  4   protein   77 non-null     int64
#  5   fat       77 non-null     int64
#  6   sodium    77 non-null     int64
#  7   fiber     77 non-null     float64
#  8   carbo     77 non-null     float64
#  9   sugars    77 non-null     int64
#  10  potass    77 non-null     int64
#  11  vitamins  77 non-null     int64
#  12  shelf     77 non-null     int64
#  13  weight    77 non-null     float64
#  14  cups      77 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 9.8+ KB

# %%
cereal_dataset.dtypes
# Out:
# name         object
# mfr          object
# type         object
# calories      int64
# protein       int64
# fat           int64
# sodium        int64
# fiber       float64
# carbo       float64
# sugars        int64
# potass        int64
# vitamins      int64
# shelf         int64
# weight      float64
# cups        float64
# rating      float64
# dtype: object

# %%
cereal_dataset.describe()
#These describes the dataset in summary.
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# min    -1.000000   -1.000000    0.000000   1.000000   0.500000   0.250000
# 25%     3.000000   40.000000   25.000000   1.000000   1.000000   0.670000
# 50%     7.000000   90.000000   25.000000   2.000000   1.000000   0.750000
# 75%    11.000000  120.000000   25.000000   3.000000   1.000000   1.000000
# max    15.000000  330.000000  100.000000   3.000000   1.500000   1.500000
#
#           rating
# count  77.000000
# mean   42.665705
# std    14.047289
# min    18.042851
# 25%    33.174094
# 50%    40.400208
# 75%    50.828392
# max    93.704912

# %%
cereal_dataset.isnull()
#This helps us to know if any of the data set is null
# Out:
#      name    mfr   type  calories  protein    fat  sodium  fiber  carbo  \
# 0   False  False  False     False    False  False   False  False  False
# 1   False  False  False     False    False  False   False  False  False
# 2   False  False  False     False    False  False   False  False  False
# 3   False  False  False     False    False  False   False  False  False
# 4   False  False  False     False    False  False   False  False  False
# ..    ...    ...    ...       ...      ...    ...     ...    ...    ...
# 72  False  False  False     False    False  False   False  False  False
# 73  False  False  False     False    False  False   False  False  False
# 74  False  False  False     False    False  False   False  False  False
# 75  False  False  False     False    False  False   False  False  False
# 76  False  False  False     False    False  False   False  False  False
#
#     sugars  potass  vitamins  shelf  weight   cups  rating
# 0    False   False     False  False   False  False   False
# 1    False   False     False  False   False  False   False
# 2    False   False     False  False   False  False   False
# 3    False   False     False  False   False  False   False
# 4    False   False     False  False   False  False   False
# ..     ...     ...       ...    ...     ...    ...     ...
# 72   False   False     False  False   False  False   False
# 73   False   False     False  False   False  False   False
# 74   False   False     False  False   False  False   False
# 75   False   False     False  False   False  False   False
# 76   False   False     False  False   False  False   False
#
# [77 rows x 16 columns]

# %%
cereal_dataset.shape
#This helps tell us the number of Rows and Columns
# Out:
# (77, 16)

# %%
cereal_dataset['mfr'].value_counts()
# Counting number of manufacturers
# Out:
# K    23
# G    22
# P     9
# Q     8
# R     8
# N     6
# A     1
# Name: mfr, dtype: int64

# %%
plt.figure(figsize = (10, 8))
sns.boxplot(x = 'mfr', y = 'rating',data=cereal_dataset)
# Out:
# <AxesSubplot:xlabel='mfr', ylabel='rating'>

# %%
cereal_dataset.corr()
#correlation table
# Out:
#           calories   protein       fat    sodium     fiber     carbo  \
# calories  1.000000  0.019066  0.498610  0.300649 -0.293413  0.250681
# protein   0.019066  1.000000  0.208431 -0.054674  0.500330 -0.130864
# fat       0.498610  0.208431  1.000000 -0.005407  0.016719 -0.318043
# sodium    0.300649 -0.054674 -0.005407  1.000000 -0.070675  0.355983
# fiber    -0.293413  0.500330  0.016719 -0.070675  1.000000 -0.356083
# carbo     0.250681 -0.130864 -0.318043  0.355983 -0.356083  1.000000
# sugars    0.562340 -0.329142  0.270819  0.101451 -0.141205 -0.331665
# potass   -0.066609  0.549407  0.193279 -0.032603  0.903374 -0.349685
# vitamins  0.265356  0.007335 -0.031156  0.361477 -0.032243  0.258148
# shelf     0.097234  0.133865  0.263691 -0.069719  0.297539 -0.101790
# weight    0.696091  0.216158  0.214625  0.308576  0.247226  0.135136
# cups      0.087200 -0.244469 -0.175892  0.119665 -0.513061  0.363932
# rating   -0.689376  0.470618 -0.409284 -0.401295  0.584160  0.052055
#
#             sugars    potass  vitamins     shelf    weight      cups    rating
# calories  0.562340 -0.066609  0.265356  0.097234  0.696091  0.087200 -0.689376
# protein  -0.329142  0.549407  0.007335  0.133865  0.216158 -0.244469  0.470618
# fat       0.270819  0.193279 -0.031156  0.263691  0.214625 -0.175892 -0.409284
# sodium    0.101451 -0.032603  0.361477 -0.069719  0.308576  0.119665 -0.401295
# fiber    -0.141205  0.903374 -0.032243  0.297539  0.247226 -0.513061  0.584160
# carbo    -0.331665 -0.349685  0.258148 -0.101790  0.135136  0.363932  0.052055
# sugars    1.000000  0.021696  0.125137  0.100438  0.450648 -0.032358 -0.759675
# potass    0.021696  1.000000  0.020699  0.360663  0.416303 -0.495195  0.380165
# vitamins  0.125137  0.020699  1.000000  0.299262  0.320324  0.128405 -0.240544
# shelf     0.100438  0.360663  0.299262  1.000000  0.190762 -0.335269  0.025159
# weight    0.450648  0.416303  0.320324  0.190762  1.000000 -0.199583 -0.298124
# cups     -0.032358 -0.495195  0.128405 -0.335269 -0.199583  1.000000 -0.203160
# rating   -0.759675  0.380165 -0.240544  0.025159 -0.298124 -0.203160  1.000000

# %%
# We observed strong positive correlation between potassium and ratings, fiber and ratings and protein and ratings.

# We observed strong negative correlation between calories and ratings, fat and ratings, sodium and ratings and sugars and ratings .

# %%
cereal_dataset.loc[cereal_dataset['mfr'] == "K"]
# Finding out what are the K cereals that have high ratings
# Out:
#                            name mfr type  calories  protein  fat  sodium  \
# 2                      All-Bran   K    C        70        4    1     260
# 3     All-Bran with Extra Fiber   K    C        50        4    0     140
# 6                   Apple Jacks   K    C       110        2    0     125
# 16                  Corn Flakes   K    C       100        2    0     290
# 17                    Corn Pops   K    C       110        1    0      90
# 19           Cracklin' Oat Bran   K    C       110        3    3     140
# 21                      Crispix   K    C       110        2    0     220
# 24                  Froot Loops   K    C       110        2    1     125
# 25               Frosted Flakes   K    C       110        1    0     200
# 26          Frosted Mini-Wheats   K    C       100        3    0       0
# 28                Fruitful Bran   K    C       120        3    0     240
# 38  Just Right Crunchy  Nuggets   K    C       110        2    1     170
# 39       Just Right Fruit & Nut   K    C       140        3    1     170
# 46         Mueslix Crispy Blend   K    C       160        3    2     150
# 48             Nut&Honey Crunch   K    C       120        2    1     190
# 49    Nutri-Grain Almond-Raisin   K    C       140        3    2     220
# 50            Nutri-grain Wheat   K    C        90        3    0     170
# 53                   Product 19   K    C       100        3    0     320
# 58                  Raisin Bran   K    C       120        3    1     210
# 60               Raisin Squares   K    C        90        2    0       0
# 62                Rice Krispies   K    C       110        2    0     290
# 66                       Smacks   K    C       110        2    1      70
# 67                    Special K   K    C       110        6    0     230
#
#     fiber  carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 2     9.0    7.0       5     320        25      3    1.00  0.33  59.425505
# 3    14.0    8.0       0     330        25      3    1.00  0.50  93.704912
# 6     1.0   11.0      14      30        25      2    1.00  1.00  33.174094
# 16    1.0   21.0       2      35        25      1    1.00  1.00  45.863324
# 17    1.0   13.0      12      20        25      2    1.00  1.00  35.782791
# 19    4.0   10.0       7     160        25      3    1.00  0.50  40.448772
# 21    1.0   21.0       3      30        25      3    1.00  1.00  46.895644
# 24    1.0   11.0      13      30        25      2    1.00  1.00  32.207582
# 25    1.0   14.0      11      25        25      1    1.00  0.75  31.435973
# 26    3.0   14.0       7     100        25      2    1.00  0.80  58.345141
# 28    5.0   14.0      12     190        25      3    1.33  0.67  41.015492
# 38    1.0   17.0       6      60       100      3    1.00  1.00  36.523683
# 39    2.0   20.0       9      95       100      3    1.30  0.75  36.471512
# 46    3.0   17.0      13     160        25      3    1.50  0.67  30.313351
# 48    0.0   15.0       9      40        25      2    1.00  0.67  29.924285
# 49    3.0   21.0       7     130        25      3    1.33  0.67  40.692320
# 50    3.0   18.0       2      90        25      3    1.00  1.00  59.642837
# 53    1.0   20.0       3      45       100      3    1.00  1.00  41.503540
# 58    5.0   14.0      12     240        25      2    1.33  0.75  39.259197
# 60    2.0   15.0       6     110        25      3    1.00  0.50  55.333142
# 62    0.0   22.0       3      35        25      1    1.00  1.00  40.560159
# 66    1.0    9.0      15      40        25      2    1.00  0.75  31.230054
# 67    1.0   16.0       3      55        25      1    1.00  1.00  53.131324

# %%
cereal_dataset.loc[cereal_dataset['mfr'] == "P"]
# Finding out what are the P cereals that have high ratings
# Out:
#                                       name mfr type  calories  protein  fat  \
# 9                              Bran Flakes   P    C        90        3    0
# 27  Fruit & Fibre Dates; Walnuts; and Oats   P    C       120        3    2
# 29                          Fruity Pebbles   P    C       110        1    1
# 30                            Golden Crisp   P    C       100        2    0
# 32                       Grape Nuts Flakes   P    C       100        3    1
# 33                              Grape-Nuts   P    C       110        3    0
# 34                      Great Grains Pecan   P    C       120        3    3
# 37                              Honey-comb   P    C       110        1    0
# 52                   Post Nat. Raisin Bran   P    C       120        3    1
#
#     sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  \
# 9      210    5.0   13.0       5     190        25      3    1.00  0.67
# 27     160    5.0   12.0      10     200        25      3    1.25  0.67
# 29     135    0.0   13.0      12      25        25      2    1.00  0.75
# 30      45    0.0   11.0      15      40        25      1    1.00  0.88
# 32     140    3.0   15.0       5      85        25      3    1.00  0.88
# 33     170    3.0   17.0       3      90        25      3    1.00  0.25
# 34      75    3.0   13.0       4     100        25      3    1.00  0.33
# 37     180    0.0   14.0      11      35        25      1    1.00  1.33
# 52     200    6.0   11.0      14     260        25      3    1.33  0.67
#
#        rating
# 9   53.313813
# 27  40.917047
# 29  28.025765
# 30  35.252444
# 32  52.076897
# 33  53.371007
# 34  45.811716
# 37  28.742414
# 52  37.840594

# %%
cereal_dataset.loc[cereal_dataset['mfr'] == "R"]
# Finding out what are the R cereals that have high ratings
# Out:
#                                  name mfr type  calories  protein  fat  \
# 4                      Almond Delight   R    C       110        2    2
# 8                           Bran Chex   R    C        90        2    1
# 15                          Corn Chex   R    C       110        2    0
# 23                        Double Chex   R    C       100        2    0
# 44   Muesli Raisins; Dates; & Almonds   R    C       150        4    3
# 45  Muesli Raisins; Peaches; & Pecans   R    C       150        4    3
# 61                          Rice Chex   R    C       110        1    0
# 74                         Wheat Chex   R    C       100        3    1
#
#     sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  \
# 4      200    1.0   14.0       8      -1        25      3     1.0  0.75
# 8      200    4.0   15.0       6     125        25      1     1.0  0.67
# 15     280    0.0   22.0       3      25        25      1     1.0  1.00
# 23     190    1.0   18.0       5      80        25      3     1.0  0.75
# 44      95    3.0   16.0      11     170        25      3     1.0  1.00
# 45     150    3.0   16.0      11     170        25      3     1.0  1.00
# 61     240    0.0   23.0       2      30        25      1     1.0  1.13
# 74     230    3.0   17.0       3     115        25      1     1.0  0.67
#
#        rating
# 4   34.384843
# 8   49.120253
# 15  41.445019
# 23  44.330856
# 44  37.136863
# 45  34.139765
# 61  41.998933
# 74  49.787445

# %%
cereal_dataset.loc[cereal_dataset['mfr'] == "Q"]
# Finding out what are the Q cereals that have high ratings
# Out:
#                   name mfr type  calories  protein  fat  sodium  fiber  carbo  \
# 1    100% Natural Bran   Q    C       120        3    5      15    2.0    8.0
# 10        Cap'n'Crunch   Q    C       120        1    2     220    0.0   12.0
# 35    Honey Graham Ohs   Q    C       120        1    2     220    1.0   12.0
# 41                Life   Q    C       100        4    2     150    2.0   12.0
# 54         Puffed Rice   Q    C        50        1    0       0    0.0   13.0
# 55        Puffed Wheat   Q    C        50        2    0       0    1.0   10.0
# 56  Quaker Oat Squares   Q    C       100        4    1     135    2.0   14.0
# 57      Quaker Oatmeal   Q    H       100        5    2       0    2.7   -1.0
#
#     sugars  potass  vitamins  shelf  weight  cups     rating
# 1        8     135         0      3     1.0  1.00  33.983679
# 10      12      35        25      2     1.0  0.75  18.042851
# 35      11      45        25      2     1.0  1.00  21.871292
# 41       6      95        25      2     1.0  0.67  45.328074
# 54       0      15         0      3     0.5  1.00  60.756112
# 55       0      50         0      3     0.5  1.00  63.005645
# 56       6     110        25      3     1.0  0.50  49.511874
# 57      -1     110         0      1     1.0  0.67  50.828392

# %%
cereal_dataset.loc[cereal_dataset['mfr'] == "A"]
# Finding out what are the A cereals that have high ratings
# Out:
#      name mfr type  calories  protein  fat  sodium  fiber  carbo  sugars  \
# 43  Maypo   A    H       100        4    1       0    0.0   16.0       3
#
#     potass  vitamins  shelf  weight  cups     rating
# 43      95        25      2     1.0   1.0  54.850917

# %%
# Highest rating cereal
cereal_dataset.loc[cereal_dataset['rating'] == max(cereal_dataset.rating)]
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 3    8.0       0     330        25      3     1.0   0.5  93.704912

# %%
# Lowest rating cereal
cereal_dataset.loc[cereal_dataset['rating'] == min(cereal_dataset.rating)]
# Out:
#             name mfr type  calories  protein  fat  sodium  fiber  carbo  \
# 10  Cap'n'Crunch   Q    C       120        1    2     220    0.0   12.0
#
#     sugars  potass  vitamins  shelf  weight  cups     rating
# 10      12      35        25      2     1.0  0.75  18.042851

# %%
print(cereal_dataset['type'].value_counts())
cereal_dataset.loc[cereal_dataset['type'] == "H"]
# Out:
# C    74
# H     3
# Name: type, dtype: int64
#                       name mfr type  calories  protein  fat  sodium  fiber  \
# 20  Cream of Wheat (Quick)   N    H       100        3    0      80    1.0
# 43                   Maypo   A    H       100        4    1       0    0.0
# 57          Quaker Oatmeal   Q    H       100        5    2       0    2.7
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 20   21.0       0      -1         0      2     1.0  1.00  64.533816
# 43   16.0       3      95        25      2     1.0  1.00  54.850917
# 57   -1.0      -1     110         0      1     1.0  0.67  50.828392

# %%
cereal_dataset.loc[cereal_dataset['type'] == "C"]
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     5.0       6     280        25      3     1.0  0.33  68.402973
# 1     8.0       8     135         0      3     1.0  1.00  33.983679
# 2     7.0       5     320        25      3     1.0  0.33  59.425505
# 3     8.0       0     330        25      3     1.0  0.50  93.704912
# 4    14.0       8      -1        25      3     1.0  0.75  34.384843
# ..    ...     ...     ...       ...    ...     ...   ...        ...
# 72   21.0       3      60        25      3     1.0  0.75  39.106174
# 73   13.0      12      25        25      2     1.0  1.00  27.753301
# 74   17.0       3     115        25      1     1.0  0.67  49.787445
# 75   17.0       3     110        25      1     1.0  1.00  51.592193
# 76   16.0       8      60        25      1     1.0  0.75  36.187559
#
# [74 rows x 16 columns]

# %%
fig = plt.figure()

plt.rcParams['figure.figsize'] = [10,10]
plt.rcParams["font.weight"] = "bold"

fontdict={'fontsize': 25,
          'weight' : 'bold'}

fontdicty={'fontsize': 18,
          'weight' : 'bold',
          'verticalalignment': 'baseline',
          'horizontalalignment': 'center'}

fontdictx={'fontsize': 18,
          'weight' : 'bold',
          'horizontalalignment': 'center'}

plt.subplots_adjust(wspace=0.2, hspace=0.2)

fig.suptitle('Can calories and macronutrients affect cereal rating?', fontsize=25,fontweight="bold", color="black", 
             position=(0.5,1.01))

ax1 = fig.add_subplot(221)
ax1.scatter('calories', 'rating', data= cereal_dataset, c="green")
ax1.set_title('Calories', fontdict=fontdict, color="green")


ax2 = fig.add_subplot(222)
ax2.scatter('fat', 'rating', data=cereal_dataset, c="orange")
ax2.set_title('Fat', fontdict=fontdict, color="orange")


ax3 = fig.add_subplot(223)
ax3.scatter('protein', 'rating', data=cereal_dataset, c="brown")
ax3.set_title('Protein', fontdict=fontdict, color="brown")

ax4 = fig.add_subplot(224)
ax4.scatter('carbo', 'rating', data=cereal_dataset, c="blue")
ax4.set_title("Carbs", fontdict=fontdict, color="blue")
# Out:
# Text(0.5, 1.0, 'Carbs')

# %%
# We can see that as the amount of calories per serving, fats and carbs increase, the rating of the cereal decreases.
# We also see a positive relationship between protein and ratings.

# %%
fig = plt.figure()

plt.rcParams['figure.figsize'] = [10,10]
plt.rcParams["font.weight"] = "bold"

fontdict={'fontsize': 25,
          'weight' : 'bold'}

fontdicty={'fontsize': 18,
          'weight' : 'bold',
          'verticalalignment': 'baseline',
          'horizontalalignment': 'center'}

fontdictx={'fontsize': 18,
          'weight' : 'bold',
          'horizontalalignment': 'center'}

plt.subplots_adjust(wspace=0.2, hspace=0.2)

fig.suptitle('Can micronutrients affect cereal rating?', fontsize=25,fontweight="bold", color="black", 
             position=(0.5,1.01))

ax1 = fig.add_subplot(221)
ax1.scatter(y='sodium', x='rating', data=cereal_dataset, c="green")
ax1.set_title('Sodium', fontdict=fontdict, color="green")


ax2 = fig.add_subplot(222)
ax2.scatter('fat', 'rating', data=cereal_dataset, c="orange")
ax2.set_title('Potassium', fontdict=fontdict, color="orange")


ax3 = fig.add_subplot(223)
ax3.scatter('fiber', 'rating', data=cereal_dataset, c="brown")
ax3.set_title('Fiber', fontdict=fontdict, color="brown")

ax4 = fig.add_subplot(224)
print(ax4.scatter('vitamins','rating',data=cereal_dataset, c="blue"))
ax4.set_title("Vitamins", fontdict=fontdict, color="blue")
# Out:
# <matplotlib.collections.PathCollection object at 0x000001C5A0797BE0>
# Text(0.5, 1.0, 'Vitamins')

# %%
# For sodium and potassium, we observed a negative relationship whereby ratings decrease as the concentration of sodium and potassium increase.
# Ratings increase as per gram of dietary fiber increases.
# Vitamins does not show a clear relationship here.

# %%
fig = plt.figure()

plt.rcParams['figure.figsize'] = [10,10]
plt.rcParams["font.weight"] = "bold"

fontdict={'fontsize': 25,
          'weight' : 'bold'}

fontdicty={'fontsize': 18,
          'weight' : 'bold',
          'verticalalignment': 'baseline',
          'horizontalalignment': 'center'}

fontdictx={'fontsize': 18,
          'weight' : 'bold',
          'horizontalalignment': 'center'}

plt.subplots_adjust(wspace=0.2, hspace=0.2)


fig.suptitle('Can sugar, display shelf level, weight and cups affect rating?', fontsize=25,fontweight="bold", color="black", 
             position=(0.5,1.01))


ax1 = fig.add_subplot(221)
ax1.scatter('sugars', 'rating', data=cereal_dataset, c="green")
ax1.set_title('Sugar', fontdict=fontdict, color="green")


ax2 = fig.add_subplot(222)
ax2.scatter('shelf', 'rating', data=cereal_dataset, c="orange")
ax2.set_title('Display shelf level', fontdict=fontdict, color="orange")


ax3 = fig.add_subplot(223)
ax3.scatter('weight', 'rating', data=cereal_dataset, c="brown")
ax3.set_title('Ounces per serving', fontdict=fontdict, color="brown")


ax4 = fig.add_subplot(224)
ax4.scatter('cups', 'rating', data=cereal_dataset, c="blue")
ax4.set_title("Cups per serving", fontdict=fontdict, color="blue")
# Out:
# Text(0.5, 1.0, 'Cups per serving')

# %%
# Ratings decrease as sugar, cups per serving and ounces per serving increases.
# Cereal at level 1 and 3 tend to fare well. I highly doubt there is a correlation between display level and rating.

# %% [markdown]
# Conclusion
#
# #Cereals with high protein and fiber tend to have a higher rating. Both protein and fiber tend to be lowly consumed in a typical diet and supplementing them in cereal will ensure a more balance diet.
#
# #Cereals with high carbohydrate, fats, sugars, sodium and calories tend to have a much lower rating.
